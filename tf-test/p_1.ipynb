# %% [markdown]
# # Face Detection

# %% [markdown]
# ## OpenCV

# %%
from deepface import DeepFace
import os
import matplotlib.pyplot as plt

absolute_path = os.path.abspath('./00000/00001.png')

#for backend in backends:
#    detected_aligned_face = DeepFace.extract_faces(img_path = absolute_path, detector_backend = backend)

face = DeepFace.detectFace('./00000/00001.png', target_size=(1024, 1024), detector_backend='opencv')

face.shape, type(face)
# Out:
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ((1024, 1024, 3), numpy.ndarray)

# %% [markdown]
# ## 여러 Backend 모델을 이용한 Face Detection 및 결과 사진 출력

# %%
fig, axs = plt.subplots(3, 2, figsize=(15,10))
axs = axs.flatten()

backends = ['opencv', 'ssd', 'dlib', 'mtcnn', 'retinaface', 'mediapipe']
#backends = ['opencv', 'mtcnn', 'retinaface']

for i, b in enumerate(backends):
    try:
        face = DeepFace.detectFace('./00000/00001.png', target_size=(1024, 1024), detector_backend=b)
        axs[i].imshow(face)
        axs[i].set_title(b)
        axs[i].axis('off')
    except:
        pass

plt.show()
# Out:
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# shape_predictor_5_face_landmarks.dat.bz2 is going to be downloaded
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ...
# 1/1 [==============================] - 0s 209ms/step
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.

# %% [markdown]
# # Facial Landmark Detection

# %% [markdown]
# ## DLib

# %%
import dlib
import cv2
import matplotlib.pyplot as plt

detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")

img = cv2.imread("./00000/00001.png")
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

faces = detector(gray)

for face in faces:
    landmarks = predictor(gray, face)
    for n in range(0, 68):
        x = landmarks.part(n).x
        y = landmarks.part(n).y
        cv2.circle(img, (x, y), 2, (255, 0, 0), -1)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %% [markdown]
# ## HRNet
